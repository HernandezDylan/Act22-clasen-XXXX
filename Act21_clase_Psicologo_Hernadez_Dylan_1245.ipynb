# %% [markdown]
# <a href="https://colab.research.google.com/github/HernandezDylan/Act22-clasen-XXXX/blob/main/Act21_clase_Psicologo_Hernadez_Dylan_1245.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Hernadez Dylan NL = 24 FECHA 24/04/2026
#
# #### Psicologo
#
# <img src="https://raw.githubusercontent.com/HernandezDylan/Act22-clasen-XXXX/refs/heads/main/EPPP%20Act%2022%20clase%20nombre%20%20en%20python%20psicologo.png" witdh="500" height="400" alt="Texto descriptivo">

# %%
class Psicologo:
    def __init__(self, nombre, telefono, edad):
        self.nombre = nombre
        self.telefono = telefono
        self.edad = edad

    def datos(self):
        print(self.nombre, self.telefono, self.edad)

    def escuchar(self, paciente):
        print(self.nombre, "escucha a", paciente)

    def diagnosticar(self, paciente):
        print(self.nombre, "diagnostica a", paciente)

    def terapia(self, paciente):
        print(paciente, "recibe terapia")

print("=== Psicologo ===")

doctor = Psicologo(
    input("Nombre: "),
    input("Teléfono: "),
    input("Edad: ")
)

while True:

    print("\n1.Datos 2.Escuchar 3.Diagnosticar 4.Terapia 5.Salir")
    op = input("Opción: ")

    if op == "1":
        doctor.datos()

    elif op == "2":
        doctor.escuchar(input("Paciente: "))

    elif op == "3":
        doctor.diagnosticar(input("Paciente: "))

    elif op == "4":
        doctor.terapia(input("Paciente: "))

    elif op == "5":
        print("Programa realizado por Hernandez Dylan 1245")
        break

    else:
        print("Error")

# %% [markdown]
# <img src="https://raw.githubusercontent.com/HernandezDylan/Act22-clasen-XXXX/refs/heads/main/TDRAN%2022.PNG" witdh="500" height="400" alt="Texto descriptivo">
